# %%
# !pip install git+https://github.com/xinyu1205/recognize-anything.git
# Out:
# ...
#   Cloning https://github.com/xinyu1205/recognize-anything.git to /tmp/pip-req-build-utcm36hw
#   Running command git clone --filter=blob:none --quiet https://github.com/xinyu1205/recognize-anything.git /tmp/pip-req-build-utcm36hw
#   Resolved https://github.com/xinyu1205/recognize-anything.git to commit 88c2b0ca13e38cca6655f83ad0185271167dbcbf
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-install-54w9xe4_/clip_fe2db3fdcf3941899660d133f01fdd2e
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-54w9xe4_/clip_fe2db3fdcf3941899660d133f01fdd2e
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
# !wget ram_plus_swin_large_14m.pth https://huggingface.co/xinyu1205/recognize-anything-plus-model/resolve/main/ram_plus_swin_large_14m.pth
# Out:
# --2024-12-29 03:33:07--  http://ram_plus_swin_large_14m.pth/
# Resolving ram_plus_swin_large_14m.pth (ram_plus_swin_large_14m.pth)... failed: Name or service not known.
# wget: unable to resolve host address ‘ram_plus_swin_large_14m.pth’
# --2024-12-29 03:33:07--  https://huggingface.co/xinyu1205/recognize-anything-plus-model/resolve/main/ram_plus_swin_large_14m.pth
# Resolving huggingface.co (huggingface.co)... 18.172.134.124, 18.172.134.4, 18.172.134.24, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.124|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
test_variable = "test"

# %%
print(test_variable)
# Out:
# test

# %%
# !ls sample_data
# Out:
# anscombe.json		     california_housing_train.csv  mnist_train_small.csv
# california_housing_test.csv  mnist_test.csv		   README.md

# %%
# !wget img1.jpg https://github.com/xinyu1205/recognize-anything/blob/main/images/1641173_2291260800.jpg
# Out:
# --2024-12-29 03:37:11--  http://img1.jpg/
# Resolving img1.jpg (img1.jpg)... failed: Name or service not known.
# wget: unable to resolve host address ‘img1.jpg’
# --2024-12-29 03:37:11--  https://github.com/xinyu1205/recognize-anything/blob/main/images/1641173_2291260800.jpg
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘1641173_2291260800.jpg’
#
# 1641173_2291260800.     [ <=>                ] 215.82K  --.-KB/s    in 0.1s
#
# 2024-12-29 03:37:12 (2.09 MB/s) - ‘1641173_2291260800.jpg’ saved [221001]
#
# FINISHED --2024-12-29 03:37:12--
# Total wall clock time: 0.6s
# Downloaded: 1 files, 216K in 0.1s (2.09 MB/s)

# %%
# !ls /content
# Out:
# 1641173_2291260800.jpg	ram_plus_swin_large_14m.pth  sample_data

# %%
# !file /content/1641173_2291260800.jpg
# Out:
# /content/1641173_2291260800.jpg: HTML document, Unicode text, UTF-8 text, with very long lines (1616)

# %%
# !python /content/rampp.py --image /content/1641173_2291260800.jpg --pretrained /content/ram_plus_swin_large_14m.pth
# Out:
# 2024-12-29 05:09:18.600156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-29 05:09:18.655167: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-29 05:09:18.672461: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-29 05:09:18.719433: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !wget tag2text_swin_14m.pth https://huggingface.co/spaces/xinyu1205/recognize-anything/resolve/main/tag2text_swin_14m.pth
# Out:
# --2024-12-29 05:12:53--  http://tag2text_swin_14m.pth/
# Resolving tag2text_swin_14m.pth (tag2text_swin_14m.pth)... failed: Name or service not known.
# wget: unable to resolve host address ‘tag2text_swin_14m.pth’
# --2024-12-29 05:12:53--  https://huggingface.co/spaces/xinyu1205/recognize-anything/resolve/main/tag2text_swin_14m.pth
# Resolving huggingface.co (huggingface.co)... 18.172.134.4, 18.172.134.124, 18.172.134.88, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python /content/tag2text.py --image /content/1641173_2291260800.jpg --pretrained /content/tag2text_swin_14m.pth
# Out:
# 2024-12-29 05:16:33.228288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-29 05:16:33.252722: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-29 05:16:33.259905: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-29 05:16:33.277224: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
